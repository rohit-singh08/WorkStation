# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('D:/PGP in Data Science and Machine Learning/4. Honeywell/US_honey_dataset (5).csv')
df
# Out:
#       Unnamed: 0         state  colonies_number  yield_per_colony  production  \
# 0              0       Alabama            16000                58      928000
# 1              1       Arizona            52000                79     4108000
# 2              2      Arkansas            50000                60     3000000
# 3              3    California           420000                93    39060000
# 4              4      Colorado            45000                60     2700000
# ...          ...           ...              ...               ...         ...
# 1110        1110      Virginia             6000                40       79000
# 1111        1111    Washington            96000                32     1206000
# 1112        1112  WestVirginia             6000                43      136000
# 1113        1113     Wisconsin            42000                47      750000
# 1114        1114       Wyoming            38000                58      242000
#
# ...

# %%
df.tail(10)
# Out:
#       Unnamed: 0         state  colonies_number  yield_per_colony  production  \
# 1105        1105   SouthDakota           250000                49     5268000
# 1106        1106     Tennessee             8000                56       81000
# 1107        1107         Texas           137000                56      384000
# 1108        1108          Utah            31000                33       92000
# 1109        1109       Vermont             7000                47       76000
# 1110        1110      Virginia             6000                40       79000
# 1111        1111    Washington            96000                32     1206000
# 1112        1112  WestVirginia             6000                43      136000
# 1113        1113     Wisconsin            42000                47      750000
# 1114        1114       Wyoming            38000                58      242000
#
#        stocks  average_price  value_of_production  year
# ...

# %%
df.head()
# Out:
#    Unnamed: 0       state  colonies_number  yield_per_colony  production  \
# 0           0     Alabama            16000                58      928000
# 1           1     Arizona            52000                79     4108000
# 2           2    Arkansas            50000                60     3000000
# 3           3  California           420000                93    39060000
# 4           4    Colorado            45000                60     2700000
#
#     stocks  average_price  value_of_production  year
# 0    28000           62.0               575000  1995
# 1   986000           68.0              2793000  1995
# 2   900000           64.0              1920000  1995
# 3  4687000           60.0             23436000  1995
# 4  1404000           68.0              1836000  1995

# %%
df = df.drop(columns = ['Unnamed: 0'])

# %%
df.shape
# Out:
# (1115, 8)

# %%
df.isnull()
# Out:
#       state  colonies_number  yield_per_colony  production  stocks  \
# 0     False            False             False       False   False
# 1     False            False             False       False   False
# 2     False            False             False       False   False
# 3     False            False             False       False   False
# 4     False            False             False       False   False
# ...     ...              ...               ...         ...     ...
# 1110  False            False             False       False   False
# 1111  False            False             False       False   False
# 1112  False            False             False       False   False
# 1113  False            False             False       False   False
# 1114  False            False             False       False   False
#
#       average_price  value_of_production   year
# 0             False                False  False
# 1             False                False  False
# ...

# %%
df.isnull().sum()
# Out:
# state                  0
# colonies_number        0
# yield_per_colony       0
# production             0
# stocks                 0
# average_price          0
# value_of_production    0
# year                   0
# dtype: int64

# %%
df.info
# Out:
# <bound method DataFrame.info of              state  colonies_number  yield_per_colony  production   stocks  \
# 0          Alabama            16000                58      928000    28000
# 1          Arizona            52000                79     4108000   986000
# 2         Arkansas            50000                60     3000000   900000
# 3       California           420000                93    39060000  4687000
# 4         Colorado            45000                60     2700000  1404000
# ...            ...              ...               ...         ...      ...
# 1110      Virginia             6000                40       79000    79000
# 1111    Washington            96000                32     1206000  1206000
# 1112  WestVirginia             6000                43      136000   136000
# 1113     Wisconsin            42000                47      750000   750000
# 1114       Wyoming            38000                58      242000   242000
#
# ...

# %%
df.describe()
# Out:
#        colonies_number  yield_per_colony    production        stocks  \
# count      1115.000000       1115.000000  1.115000e+03  1.115000e+03
# mean      62438.565022         59.743498  2.851268e+06  1.172625e+06
# std       92648.175955         19.940500  5.561202e+06  2.049556e+06
# min        2000.000000         19.000000  1.200000e+04  9.000000e+03
# 25%        9000.000000         45.000000  2.460000e+05  1.125000e+05
# 50%       26000.000000         57.000000  8.280000e+05  3.700000e+05
# 75%       69000.000000         71.000000  2.700000e+06  1.253500e+06
# max      550000.000000        155.000000  3.906000e+07  1.354500e+07
#
#        average_price  value_of_production         year
# count    1115.000000         1.115000e+03  1115.000000
# mean      140.623076         5.667412e+06  2007.740807
# std       107.011544         9.459460e+06     7.823002
# min         1.300000         1.060000e+05  1995.000000
# 25%        70.000000         1.008000e+06  2001.000000
# ...

# %%
df['state'].unique()
# Out:
# array(['Alabama', 'Arizona', 'Arkansas', 'California', 'Colorado',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana',
#        'Nebraska', 'Nevada', 'NewJersey', 'NewMexico', 'NewYork',
#        'NorthCarolina', 'NorthDakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'SouthCarolina', 'SouthDakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'WestVirginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
df.production.max()
# Out:
# 39060000

# %%
print(df.state)
# Out:
# 0            Alabama
# 1            Arizona
# 2           Arkansas
# 3         California
# 4           Colorado
#             ...
# 1110        Virginia
# 1111      Washington
# 1112    WestVirginia
# 1113       Wisconsin
# 1114         Wyoming
# Name: state, Length: 1115, dtype: object

# %%
df2 = df.sort_values('production', ascending = False)
df2
# Out:
#              state  colonies_number  yield_per_colony  production    stocks  \
# 3       California           420000                93    39060000   4687000
# 134     California           450000                83    37350000  12326000
# 581    NorthDakota           390000                90    35100000   8424000
# 622    NorthDakota           450000                77    34650000   7623000
# 458    NorthDakota           370000                91    33670000   8418000
# ..             ...              ...               ...         ...       ...
# 769       Kentucky             3000                41       17000     17000
# 984  SouthCarolina            16000                48       15000     15000
# 955        Alabama             6000                45       14000     14000
# 835        Alabama             7000                47       13000     13000
# 689       Kentucky             4000                39       12000     12000
#
#      average_price  value_of_production  year
# ...

# %%
df2.head(1)
# Out:
#         state  colonies_number  yield_per_colony  production   stocks  \
# 3  California           420000                93    39060000  4687000
#
#    average_price  value_of_production  year
# 3           60.0             23436000  1995

# %%
plt.figure(figsize=(15,9))
sns.barplot(x=df['production'], y=df['state'])
plt.xlabel('Total production of Honey')
plt.ylabel('State')
plt.plot()
plt.savefig('Bar Plot.png')

# %%
plt.figure(figsize=(15,9))
sns.barplot(x=df2['production'], y=df2['state'])
plt.xlabel('Total production of Honey')
plt.ylabel('State')
plt.plot()
# Out:
# []

# %%
#mean by year
df1 = df.groupby("year").mean()
df1
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17648\1010404906.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df1 = df.groupby("year").mean()
#       colonies_number  yield_per_colony    production        stocks  \
# year
# 1995     59977.272727         66.909091  4.778909e+06  9.575000e+05
# 1996     58181.818182         70.068182  4.499886e+06  1.066455e+06
# 1997     59651.162791         68.953488  4.445953e+06  1.601256e+06
# 1998     60883.720930         69.953488  5.100488e+06  1.871488e+06
# 1999     62186.046512         65.465116  4.757791e+06  1.839698e+06
# 2000     60860.465116         67.534884  5.123721e+06  1.997395e+06
# 2001     58139.534884         65.209302  4.311698e+06  1.501791e+06
# 2002     57181.818182         67.272727  3.880273e+06  8.831591e+05
# ...

# %%
df1 = df1.reset_index()

# %%
plt.figure(figsize=(15,9))
sns.barplot(x=df1["year"], y=df1["average_price"])
plt.xlabel('Year(1995-2021)')
plt.ylabel('Average Price of Honey')
plt.plot()
plt.savefig('Average Price of Honey vs Year')

# %%
df1[df1["production"] == df1["production"].max()]
# Out:
#    year  colonies_number  yield_per_colony    production        stocks  \
# 5  2000     60860.465116         67.534884  5.123721e+06  1.997395e+06
#
#    average_price  value_of_production
# 5      79.023256         3.047023e+06

# %%
df1["year"][df1["production"] == df1["production"].max()]
# Out:
# 5    2000
# Name: year, dtype: int64

# %%
plt.figure(figsize=(15,9))
sns.barplot(x=df1["year"], y=df1["production"])
plt.xlabel('Year(1995-2021)')
plt.ylabel('Total Honey Production(Pounds)')
plt.plot()
plt.savefig('Total Honey Production vs Year.png')

# %%
plt.figure(figsize=(10,10))
plt.pie(df1["production"], labels = df1['year'], autopct = "1%.2f%%")
plt.plot()
plt.savefig('% Distribution per Year')

# %%
plt.plot(df1['year'], df1["production"])
plt.show()
plt.savefig('Total Honey Production vs Year')

# %%
df2 = df.groupby(['year']).mean()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17648\1976868944.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df2 = df.groupby(['year']).mean()

# %%
df2 = df2.reset_index()

# %%
df2.sort_values("value_of_production" , ascending = False)
# Out:
#     year  colonies_number  yield_per_colony    production        stocks  \
# 19  2014     67725.000000         57.350000  1.024750e+06  1.024750e+06
# 21  2016     68500.000000         54.075000  1.020925e+06  1.020925e+06
# 23  2018     69800.000000         50.875000  7.247250e+05  7.247250e+05
# 22  2017     66225.000000         53.425000  7.619500e+05  7.619500e+05
# 18  2013     66846.153846         52.974359  9.736923e+05  9.736923e+05
# 20  2015     65750.000000         55.325000  1.045800e+06  1.045800e+06
# 26  2021     66700.000000         46.700000  5.796750e+05  5.796750e+05
# 24  2019     69550.000000         51.050000  1.012750e+06  1.012750e+06
# 25  2020     66825.000000         50.000000  9.853000e+05  9.853000e+05
# 17  2012     62725.000000         55.175000  7.915500e+05  7.915500e+05
# 15  2010     66650.000000         56.275000  1.119925e+06  1.119925e+06
# 16  2011     61650.000000         54.775000  9.137500e+05  9.137500e+05
# ...

# %%
plt.figure(figsize=(15,9))
sns.barplot(x=df2["year"], y=df2["value_of_production"])
plt.xlabel('Year(1995-2021)')
plt.ylabel('Value of production(Dollar)')
plt.plot()
plt.savefig('Value of production(Dollar) vs Year')

# %%
plt.figure(figsize=(15,9))
sns.scatterplot(x=df2["year"], y=df2["value_of_production"])
plt.xlabel('Year(1995-2021)')
plt.ylabel('Value of production(Dollar)')
plt.plot()
plt.savefig('Value of production(Dollar) vs Year')

# %%
plt.figure(figsize=(10,10))
plt.pie(df2["value_of_production"], labels = df2['year'], autopct = "1%.1f%%")
plt.plot()
plt.savefig('Pie Graph of Value of Production')

# %%
df3 = df.groupby('state').sum()
df3 = df3.reset_index()
df3
# Out:
#             state  colonies_number  yield_per_colony  production     stocks  \
# 0         Alabama           288000              1615    14467000    2987000
# 1         Arizona           854000              1490    38844000   17758000
# 2        Arkansas           908000              1886    51846000   20897000
# 3      California         10135000              1426   423876000  137611000
# 4        Colorado           799000              1520    32660000   18695000
# 5         Florida          5528000              1956   280934000   47037000
# 6         Georgia          1917000              1354    57426000    9932000
# 7          Hawaii           296000              2802    15420000    3508000
# 8           Idaho          2705000              1121    87188000   40503000
# 9        Illinois           236000              1562     9864000    4957000
# 10        Indiana           213000              1605     9686000    5286000
# ...

# %%
plt.figure(figsize=(15,9))
sns.barplot(x=df3["stocks"], y=df3["state"])
plt.xlabel('Number of Stocks')
plt.ylabel('State)')
plt.plot()
plt.savefig('Number of Stock per State')
